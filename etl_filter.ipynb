# %%
import pandas as pd
import json
from sqlalchemy import create_engine
engine = create_engine('postgresql://bi_user:password@66.94.120.221:5432/testdb')

# %%
url = "https://data.cityofchicago.org/resource/ijzp-q8t2.json"

# %%
json_data = pd.read_json(url)
json_data.head(2)
# Out:
#          id case_number                date                 block  iucr  \
# 0  12485372    JE377024 2021-09-14 23:56:00  001XX N PARKSIDE AVE  0265
# 1  12482818    JE373979 2021-09-14 23:50:00       001XX W 71ST ST  1812
#
#               primary_type                            description  \
# 0  CRIMINAL SEXUAL ASSAULT                     AGGRAVATED - OTHER
# 1                NARCOTICS  POSSESS - CANNABIS MORE THAN 30 GRAMS
#
#   location_description  arrest  domestic  ...  longitude  \
# 0                ALLEY   False     False  ... -87.766608
# 1               STREET    True     False  ... -87.629072
#
#                                             location  \
# 0  {'latitude': '41.88314073', 'longitude': '-87....
# 1  {'latitude': '41.765446324', 'longitude': '-87...
#
#    :@computed_region_awaf_s7ux  :@computed_region_6mkv_f3dw  \
# 0                         52.0                      22216.0
# 1                         31.0                      21559.0
#
#   :@computed_region_vrxf_vc4k  :@computed_region_bdys_3d7i  \
# 0                        26.0                        618.0
# 1                        67.0                        494.0
#
#    :@computed_region_43wa_7qmu  :@computed_region_rpca_8um6  \
# 0                          7.0                         32.0
# 1                         32.0                         11.0
#
#   :@computed_region_d9mm_jgwp  :@computed_region_d3ds_rm58
# 0                        25.0                         85.0
# 1                        17.0                        210.0
#
# [2 rows x 30 columns]

# %%
json_data.describe()
# Out:
#                  id         beat     district         ward  community_area  \
# count  1.000000e+03  1000.000000  1000.000000  1000.000000     1000.000000
# mean   1.242029e+07  1144.579000    11.213000    22.403000       37.536000
# std    8.790282e+05   692.864469     6.925142    14.123104       21.941607
# min    2.628100e+04   111.000000     1.000000     1.000000        1.000000
# 25%    1.248175e+07   611.000000     6.000000     9.000000       23.000000
# 50%    1.248236e+07  1022.000000    10.000000    21.000000       32.000000
# 75%    1.248285e+07  1723.000000    17.000000    34.000000       56.000000
# max    1.248899e+07  2535.000000    25.000000    50.000000       77.000000
#
#        x_coordinate  y_coordinate    year    latitude   longitude  \
# count  9.830000e+02  9.830000e+02  1000.0  983.000000  983.000000
# mean   1.165597e+06  1.884649e+06  2021.0   41.839050  -87.667880
# std    1.688121e+04  3.248220e+04     0.0    0.089342    0.061419
# min    1.100658e+06  1.814512e+06  2021.0   41.645796  -87.905227
# 25%    1.153871e+06  1.857834e+06  2021.0   41.765005  -87.710310
# 50%    1.167555e+06  1.890572e+06  2021.0   41.855069  -87.660922
# 75%    1.176614e+06  1.908573e+06  2021.0   41.904998  -87.627514
# max    1.204544e+06  1.950365e+06  2021.0   42.019529  -87.527258
#
#        :@computed_region_awaf_s7ux  :@computed_region_6mkv_f3dw  \
# count                   982.000000                   983.000000
# mean                     28.258656                 19072.653103
# std                      14.933570                  5709.012496
# min                       1.000000                  4299.000000
# 25%                      16.000000                 21184.000000
# 50%                      30.000000                 21560.000000
# 75%                      41.000000                 22216.000000
# max                      53.000000                 22620.000000
#
#        :@computed_region_vrxf_vc4k  :@computed_region_bdys_3d7i  \
# count                   982.000000                   981.000000
# mean                     39.667006                   385.955148
# std                      19.733911                   239.929590
# min                       1.000000                     1.000000
# 25%                      26.000000                   167.000000
# 50%                      37.000000                   399.000000
# 75%                      58.000000                   587.000000
# max                      76.000000                   801.000000
#
#        :@computed_region_43wa_7qmu  :@computed_region_rpca_8um6  \
# count                   982.000000                   982.000000
# mean                     25.970468                    31.697556
# std                      14.305753                    18.888135
# min                       1.000000                     1.000000
# 25%                      13.000000                    16.000000
# 50%                      26.500000                    30.000000
# 75%                      37.000000                    49.750000
# max                      50.000000                    61.000000
#
#        :@computed_region_d9mm_jgwp  :@computed_region_d3ds_rm58
# count                   982.000000                   982.000000
# mean                     15.041752                   151.848269
# std                       6.280992                    78.910745
# min                       1.000000                     4.000000
# 25%                      10.000000                    86.000000
# 50%                      16.000000                   153.500000
# 75%                      20.000000                   225.000000
# max                      25.000000                   277.000000

# %%
json_data.columns
# Out:
# Index(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'x_coordinate',
#        'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
#        'location', ':@computed_region_awaf_s7ux',
#        ':@computed_region_6mkv_f3dw', ':@computed_region_vrxf_vc4k',
#        ':@computed_region_bdys_3d7i', ':@computed_region_43wa_7qmu',
#        ':@computed_region_rpca_8um6', ':@computed_region_d9mm_jgwp',
#        ':@computed_region_d3ds_rm58'],
#       dtype='object')

# %%
json_data.to_sql('crime_data', engine)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1779                     self.dialect.do_executemany(
# -> 1780                         cursor, statement, parameters, context
#    1781                     )
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     967                 fetch=bool(context.compiled.returning),
# --> 968                 **kwargs
#     969             )
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1266         for args in page:
# -> 1267             parts.append(cur.mogrify(template, args))
#    1268             parts.append(b',')
#
# ProgrammingError: can't adapt type 'dict'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-65-fa3b35ad9b7a> in <module>
# ----> 1 json_data.to_sql('crime_data', engine)
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2613             chunksize=chunksize,
#    2614             dtype=dtype,
# -> 2615             method=method,
#    2616         )
#    2617
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     596         chunksize=chunksize,
#     597         dtype=dtype,
# --> 598         method=method,
#     599     )
#     600
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1284             )
#    1285         else:
# -> 1286             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1287
#    1288     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     322         if _force or self.supports_execution:
#     323             return connection._execute_clauseelement(
# --> 324                 self, multiparams, params, execution_options
#     325             )
#     326         else:
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1486             elem,
#    1487             extracted_params,
# -> 1488             cache_hit=cache_hit,
#    1489         )
#    1490         if has_events:
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841         except BaseException as e:
#    1842             self._handle_dbapi_exception(
# -> 1843                 e, statement, parameters, cursor, context
#    1844             )
#    1845
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2022             elif should_wrap:
#    2023                 util.raise_(
# -> 2024                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2025                 )
#    2026             else:
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1778                 if not evt_handled:
#    1779                     self.dialect.do_executemany(
# -> 1780                         cursor, statement, parameters, context
#    1781                     )
#    1782             elif not parameters and context.no_parameters:
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     966                 template=executemany_values,
#     967                 fetch=bool(context.compiled.returning),
# --> 968                 **kwargs
#     969             )
#     970
#
# ~\azuredatastudio-python\0.0.1\lib\site-packages\psycopg2\extras.py in execute_values(cur, sql, argslist, template, page_size, fetch)
#    1265         parts = pre[:]
#    1266         for args in page:
# -> 1267             parts.append(cur.mogrify(template, args))
#    1268             parts.append(b',')
#    1269         parts[-1:] = post
#
# ProgrammingError: (psycopg2.ProgrammingError) can't adapt type 'dict'
# [SQL: INSERT INTO crime_data (index, id, case_number, date, block, iucr, primary_type, description, location_description, arrest, domestic, beat, district, ward, community_area, fbi_code, x_coordinate, y_coordinate, year, updated_on, latitude, longitude, location, ":@computed_region_awaf_s7ux", ":@computed_region_6mkv_f3dw", ":@computed_region_vrxf_vc4k", ":@computed_region_bdys_3d7i", ":@computed_region_43wa_7qmu", ":@computed_region_rpca_8um6", ":@computed_region_d9mm_jgwp", ":@computed_region_d3ds_rm58") VALUES (%(index)s, %(id)s, %(case_number)s, %(date)s, %(block)s, %(iucr)s, %(primary_type)s, %(description)s, %(location_description)s, %(arrest)s, %(domestic)s, %(beat)s, %(district)s, %(ward)s, %(community_area)s, %(fbi_code)s, %(x_coordinate)s, %(y_coordinate)s, %(year)s, %(updated_on)s, %(latitude)s, %(longitude)s, %(location)s, %(:@computed_region_awaf_s7ux)s, %(:@computed_region_6mkv_f3dw)s, %(:@computed_region_vrxf_vc4k)s, %(:@computed_region_bdys_3d7i)s, %(:@computed_region_43wa_7qmu)s, %(:@computed_region_rpca_8um6)s, %(:@computed_region_d9mm_jgwp)s, %(:@computed_region_d3ds_rm58)s)]
# [parameters: ({'index': 0, 'id': 12485372, 'case_number': 'JE377024', 'date': datetime.datetime(2021, 9, 14, 23, 56), 'block': '001XX N PARKSIDE AVE', 'iucr': '0265', 'primary_type': 'CRIMINAL SEXUAL ASSAULT', 'description': 'AGGRAVATED - OTHER', 'location_description': 'ALLEY', 'arrest': False, 'domestic': False, 'beat': 1512, 'district': 15, 'ward': 29, 'community_area': 25, 'fbi_code': '02', 'x_coordinate': 1138575.0, 'y_coordinate': 1900516.0, 'year': 2021, 'updated_on': '2021-09-21T16:49:15.000', 'latitude': 41.88314073, 'longitude': -87.76660788, 'location': {'latitude': '41.88314073', 'longitude': '-87.76660788', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': 52.0, ':@computed_region_6mkv_f3dw': 22216.0, ':@computed_region_vrxf_vc4k': 26.0, ':@computed_region_bdys_3d7i': 618.0, ':@computed_region_43wa_7qmu': 7.0, ':@computed_region_rpca_8um6': 32.0, ':@computed_region_d9mm_jgwp': 25.0, ':@computed_region_d3ds_rm58': 85.0}, {'index': 1, 'id': 12482818, 'case_number': 'JE373979', 'date': datetime.datetime(2021, 9, 14, 23, 50), 'block': '001XX W 71ST ST', 'iucr': '1812', 'primary_type': 'NARCOTICS', 'description': 'POSSESS - CANNABIS MORE THAN 30 GRAMS', 'location_description': 'STREET', 'arrest': True, 'domestic': False, 'beat': 731, 'district': 7, 'ward': 6, 'community_area': 69, 'fbi_code': '18', 'x_coordinate': 1176379.0, 'y_coordinate': 1857906.0, 'year': 2021, 'updated_on': '2021-09-21T16:49:15.000', 'latitude': 41.765446324, 'longitude': -87.62907249, 'location': {'latitude': '41.765446324', 'longitude': '-87.62907249', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': 31.0, ':@computed_region_6mkv_f3dw': 21559.0, ':@computed_region_vrxf_vc4k': 67.0, ':@computed_region_bdys_3d7i': 494.0, ':@computed_region_43wa_7qmu': 32.0, ':@computed_region_rpca_8um6': 11.0, ':@computed_region_d9mm_jgwp': 17.0, ':@computed_region_d3ds_rm58': 210.0}, {'index': 2, 'id': 12482797, 'case_number': 'JE373963', 'date': datetime.datetime(2021, 9, 14, 23, 48), 'block': '040XX W 30TH ST', 'iucr': '143A', 'primary_type': 'WEAPONS VIOLATION', 'description': 'UNLAWFUL POSSESSION - HANDGUN', 'location_description': 'STREET', 'arrest': True, 'domestic': False, 'beat': 1031, 'district': 10, 'ward': 22, 'community_area': 30, 'fbi_code': '15', 'x_coordinate': 1149760.0, 'y_coordinate': 1884400.0, 'year': 2021, 'updated_on': '2021-09-21T16:49:15.000', 'latitude': 41.838706452, 'longitude': -87.72595418, 'location': {'latitude': '41.838706452', 'longitude': '-87.72595418', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': 14.0, ':@computed_region_6mkv_f3dw': 21569.0, ':@computed_region_vrxf_vc4k': 32.0, ':@computed_region_bdys_3d7i': 248.0, ':@computed_region_43wa_7qmu': 28.0, ':@computed_region_rpca_8um6': 57.0, ':@computed_region_d9mm_jgwp': 21.0, ':@computed_region_d3ds_rm58': 167.0}, {'index': 3, 'id': 12482833, 'case_number': 'JE374011', 'date': datetime.datetime(2021, 9, 14, 23, 45), 'block': '089XX S COMMERCIAL AVE', 'iucr': '0486', 'primary_type': 'BATTERY', 'description': 'DOMESTIC BATTERY SIMPLE', 'location_description': 'APARTMENT', 'arrest': True, 'domestic': True, 'beat': 423, 'district': 4, 'ward': 10, 'community_area': 46, 'fbi_code': '08B', 'x_coordinate': 1197698.0, 'y_coordinate': 1846203.0, 'year': 2021, 'updated_on': '2021-09-21T16:49:15.000', 'latitude': 41.732826881, 'longitude': -87.551322889, 'location': {'latitude': '41.732826881', 'longitude': '-87.551322889', 'human_address': '{"address": "", "city": "", "state": "", "zip": ""}'}, ':@computed_region_awaf_s7ux': 47.0, ':@computed_region_6mkv_f3dw': 21202.0, ':@computed_region_vrxf_vc4k': 42.0, ':@computed_region_bdys_3d7i': 175.0, ':@computed_region_43wa_7qmu': 47.0, ':@computed_region_rpca_8um6': 25.0, ':@computed_region_d9mm_jgwp': 19.0, ':@computed_region_d3ds_rm58': 238.0}, {'index': 4, 'id': 12483727, 'case_ ...
# (Background on this error at: https://sqlalche.me/e/14/f405)
